# %%
#1.Identify and fix the syntax error in the following code:


age = 18
if age >= 18
    print("You are eligible to vote")

# %%
# __Curly braces and semicolon is missing in condition__
if (age>=18):
    print("You are eligible to vote")
# Out:
# You are eligible to vote

# %%
#2.Question:
What error will occur in the following code?


def greet():
    print("Hello, World!")

greet_user()

# %%
#__name greet_user() is not defined__
def greet():
    print("Hello World!")

greet()
# Out:
# Hello World!

# %%
#3.Identify the error in this code:

name = "Alice"
age = 25
print("My name is " + name + " and I am " + age + " years old.")

# %%
# TypeError: cannot concat with string object with int

name = "Alice"
age = 25
print(f"My name is {name} and I am {age} years old.")
# Out:
# My name is Alice and I am 25 years old.

# %%
#4.Question:
What will happen when you run this code?

a = 10
b = 0
result = a / b
print(result)

# %%
# occurs an Exception
# ZeroDivisionError
# we need to use try and except block to handle this

# %%
a = 10
b =0
try:
    result = a/b
except Exception as e:
    print(e)
# Out:
# division by zero

# %%
#5.What error will occur in the following code?

num = int("xyz")
print(num)

# %%
# Value Error: int object cannot accept String

# %%
#6.Identify the issue in this code:

data = {"name": "John", "age": 30}
print(data["city"])

# %%
# KeyError : data dict does not contain key city

# %%
#7.What will happen when you run this code?
num = 1
while num < 5:
    print(num)

# %%
# keeps on executing until it becomes false

# %%
#8.What is wrong with this code?

fruits = ("apple", "banana", "cherry")
print(fruits[3])

# %%
# IndexError : Index is out of range

# %%
#9.What will happen when you run this code?

text = "hello world"
text.append("!")

# %%
# str object does not have append method

# AttributeError: 'str' object has no attribute 'append'

# %%
#10.What is wrong with the following code?

import randoms
print(randoms.randint(1, 10))

# %%
# ModuleNotFoundError: No module named 'randoms'

# %%
import random
print(random.randint(1,10))
# Out:
# 3

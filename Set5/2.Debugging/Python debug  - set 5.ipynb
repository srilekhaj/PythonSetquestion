# %%
#1.What is wrong with the following code?


for i in range(5):
print(i)

# %%
Indentation Error: print statment should contain inside the loop
for i in range(5):
    print(i)

# %%
#2.Question:
Identify and fix the syntax error in this code:

numbers = [1, 2, 3, 4, 5,)

# %%
SyntaxError : either should declare using the single data structures
if declared with list should start with square bracket and end with square bracket
if declared with tuple should start with parenthesis and end with parathesis


numbers = [1,2,3,4,5]
numbers = (1,2,3,4,5)

# %%
#3.What error will occur in this code if the file does not exist?

file = open("data.txt", "r")
print(file.read())
file.close()

# %%
FileNotFoundError

# %%
#4.What is wrong with this code?

numbers = [10, 20, 30, 40]
index = "2"
print(numbers[index])

# %%
TypeError: index must be declared in integer

# %%
#5.What is the issue with this function?

def is_prime(n):
    for i in range(2, n):
        if n % i == 0:
            return True
    return False

# %%
Logical Error  if n % i is zero from 2 to n then it is not a prime 

n=5
2%5==0 False
3%5==0 False
4%5==0 False

is_prime(5):
prints false, it concludes it is not prime

# %%
#6.What is the issue with this function?

def filter_even(numbers):
    return [num for num in numbers if num % 2 == 1]

# %%
Logical Error 
for evennumbers logic is number mod 2 is zero but it is written as 1

# %%
#7.Question:
What will happen when you run this code?

numbers = [3, 1, 4, 1, 5, 9]
sorted_numbers = numbers.sort()
print(sorted_numbers)

# %%
SyntaxError
no need for variable assignment for perfoming sort function

# %%
#8.What is the issue with this function?

def sum_numbers(numbers):
    total = 1
    for num in numbers:
        total += num
    return total

# %%
Logical Error  :total should be zero for sum of numbers additionally it is incremented by 1

# %%
#9.What is the issue with this recursive function?

def factorial(n):
    return n * factorial(n-1)

# %%
SyntaxError or RecursionError
there is not base condition to conclude the result

# %%
#10.What will happen when you run this code?

data = {"name": "Alice", "age": 25}
data["city"] += "New York"

# %%
KeyError : key city not found in data
